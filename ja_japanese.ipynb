# %%
# !git clone --branch japan https://github.com/Kussssssss/comsl_ja_cy_id
# %cd comsl_ja_cy_id
# Out:
# Cloning into 'comsl_ja_cy_id'...
# remote: Enumerating objects: 211, done.
# remote: Counting objects: 100% (211/211), done.
# remote: Compressing objects: 100% (141/141), done.
# remote: Total 211 (delta 89), reused 187 (delta 66), pack-reused 0 (from 0)
# Receiving objects: 100% (211/211), 7.72 MiB | 19.36 MiB/s, done.
# Resolving deltas: 100% (89/89), done.
# /kaggle/working/comsl_ja_cy_id

# %% [markdown]
# # Install

# %%
# !pip install numpy==1.26.4 --force-reinstall -qq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 90.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.2 which is incompatible.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.1 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pandas-gbq 0.28.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.

# %%
# !pip install transformers==4.29.1 pytorch_lightning==2.0.2 deepspeed==0.9.2 ffmpeg-python more_itertools==9.1.0 PyYAML==6.0 regex==2022.10.31 sacrebleu==2.3.1 torchmetrics==0.11.4 tqdm==4.64.0 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.3/779.3 kB 17.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 88.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.0/719.0 kB 35.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.9/757.9 kB 34.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.1/781.1 kB 38.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 75.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 73.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 28.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 2.8 MB/s eta 0:00:00
#   Building wheel for deepspeed (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sigstore 3.6.2 requires pydantic<3,>=2, but you have pydantic 1.10.22 which is incompatible.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# datasets 3.6.0 requires tqdm>=4.66.3, but you have tqdm 4.64.0 which is incompatible.
# sigstore-rekor-types 0.0.18 requires pydantic[email]<3,>=2, but you have pydantic 1.10.22 which is incompatible.
# ydata-profiling 4.16.1 requires pydantic>=2, but you have pydantic 1.10.22 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.64.0 which is incompatible.
# kaggle-environments 1.16.11 requires transformers>=4.33.1, but you have transformers 4.29.1 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.9.1 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# dopamine-rl 4.1.2 requires tqdm>=4.64.1, but you have tqdm 4.64.0 which is incompatible.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.29.1 which is incompatible.
# langchain-core 0.3.50 requires packaging<25,>=23.2, but you have packaging 25.0 which is incompatible.
# langchain-core 0.3.50 requires pydantic<3.0.0,>=2.5.2; python_full_version < "3.12.4", but you have pydantic 1.10.22 which is incompatible.
# langchain 0.3.22 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.22 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 44.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.0.0 which is incompatible.
# google-genai 1.9.0 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.22 which is incompatible.
# albumentations 2.0.5 requires pydantic>=2.9.2, but you have pydantic 1.10.22 which is incompatible.

# %%
import warnings
warnings.filterwarnings("ignore", message="dataloader_idx is None")
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Create forder for logs

# %%
import os

output_path = "/kaggle/working/comsl_ja_cy_id/output/comsl_ja2en/logs"
os.makedirs(output_path, exist_ok=True)
print(f"Đã tạo thư mục: {output_path}")
# Out:
# Đã tạo thư mục: /kaggle/working/comsl_ja_cy_id/output/comsl_ja2en/logs

# %% [markdown]
# # Remove logs (in case of re-running)

# %%
import os
import glob

log_dir = '/kaggle/working/comsl_ja_cy_id/output/comsl_ja2en/logs'

# Xóa tất cả file trong thư mục log_dir
for file_path in glob.glob(os.path.join(log_dir, '*')):
    try:
        os.remove(file_path)
    except IsADirectoryError:
        pass

# %% [markdown]
# # Execute

# %%
# !python /kaggle/working/comsl_ja_cy_id/run.py --config comsl.yaml
# Out:
# 2025-06-02 01:45:09.824917: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748828710.051060     133 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748828710.109976     133 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/deepspeed/runtime/zero/linear.py:47: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @autocast_custom_fwd
# /usr/local/lib/python3.11/dist-packages/deepspeed/runtime/zero/linear.py:66: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @autocast_custom_bwd
# Loaded 1119 japanese to english data pairs.
# Loaded 150 japanese to english data pairs.
# Loaded 150 japanese to english data pairs.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json: 100%|███████████████████| 529/529 [00:00<00:00, 3.66MB/s]
# sentencepiece.bpe.model: 100%|█████████████| 5.07M/5.07M [00:00<00:00, 10.4MB/s]
# special_tokens_map.json: 100%|█████████████████| 649/649 [00:00<00:00, 3.13MB/s]
# config.json: 100%|█████████████████████████| 1.43k/1.43k [00:00<00:00, 8.08MB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# model.safetensors: 100%|████████████████████| 2.44G/2.44G [00:14<00:00, 173MB/s]
# generation_config.json: 100%|██████████████████| 261/261 [00:00<00:00, 1.41MB/s]
# 100%|█████████████████████████████████████| 72.1M/72.1M [00:01<00:00, 73.2MiB/s]
# /usr/local/lib/python3.11/dist-packages/lightning_fabric/connector.py:562: UserWarning: 16 is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
#   rank_zero_warn(
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/plugins/precision/amp.py:47: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:189: UserWarning: .fit(ckpt_path="last") is set, but there is no last checkpoint available. No checkpoint will be loaded.
#   rank_zero_warn(
# Sanity Checking DataLoader 0:   0%|                       | 0/2 [00:00<?, ?it/s]warning: dataloader_idx is None
# Sanity Checking DataLoader 0:  50%|███████▌       | 1/2 [00:02<00:02,  2.31s/it]warning: dataloader_idx is None
# Sanity Checking DataLoader 0: 100%|███████████████| 2/2 [00:04<00:00,  2.10s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(24.4462, device='cuda:0')
# val_wer_epoch tensor(1., device='cuda:0')
# val_speech_nll_loss_epoch tensor(7.4863, device='cuda:0')
# val_speech_acc_epoch tensor(25., device='cuda:0')
# val_asr_nll_loss_epoch tensor(6.6976, device='cuda:0')
# val_asr_acc_epoch tensor(9.0909, device='cuda:0')
# val_text_nll_loss_epoch tensor(1.5630, device='cuda:0')
# val_text_acc_epoch tensor(75., device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(7.8125, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(6.4347, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(9.3207, device='cuda:0')
# val_mix_speech_acc_epoch tensor(20., device='cuda:0')
# val_mix_asr_acc_epoch tensor(13.6364, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(25., device='cuda:0')
# val_guide_loss_epoch tensor(7.5992, device='cuda:0')
# val_reg_loss_epoch tensor(0.3829, device='cuda:0')
# Epoch 0: 100%|█| 1119/1119 [11:17<00:00,  1.65it/s, v_num=ault, train_acc_asr=30
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:01<00:42,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:02<00:44,  1.24s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:03<00:39,  1.13s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:05<00:42,  1.25s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:06<00:41,  1.27s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:07<00:40,  1.27s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:09<00:41,  1.33s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:10<00:40,  1.36s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:12<00:38,  1.34s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:13<00:37,  1.33s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:14<00:36,  1.34s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:16<00:34,  1.34s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:17<00:34,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:19<00:32,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:20<00:31,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:21<00:30,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:23<00:29,  1.41s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:25<00:27,  1.40s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:26<00:26,  1.39s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:27<00:24,  1.38s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:29<00:23,  1.39s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:30<00:22,  1.38s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:31<00:20,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:32<00:19,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:34<00:17,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:35<00:16,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:36<00:14,  1.36s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:38<00:13,  1.36s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:39<00:12,  1.35s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:40<00:10,  1.35s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:41<00:09,  1.34s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:43<00:08,  1.36s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:45<00:06,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:46<00:05,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:48<00:04,  1.38s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:49<00:02,  1.38s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:50<00:01,  1.38s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:52<00:00,  1.38s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(31.2017, device='cuda:0')
# val_wer_epoch tensor(8.9800, device='cuda:0')
# val_speech_nll_loss_epoch tensor(4.0650, device='cuda:0')
# val_speech_acc_epoch tensor(38.6905, device='cuda:0')
# val_asr_nll_loss_epoch tensor(4.9772, device='cuda:0')
# val_asr_acc_epoch tensor(28.1124, device='cuda:0')
# val_text_nll_loss_epoch tensor(1.3060, device='cuda:0')
# val_text_acc_epoch tensor(69.6429, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(3.7295, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(5.1004, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(6.1156, device='cuda:0')
# val_mix_speech_acc_epoch tensor(35.3175, device='cuda:0')
# val_mix_asr_acc_epoch tensor(27.5100, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(19.4805, device='cuda:0')
# val_guide_loss_epoch tensor(4.2013, device='cuda:0')
# val_reg_loss_epoch tensor(0.4040, device='cuda:0')
# Epoch 0: 100%|█| 1119/1119 [12:10<00:00,  1.53it/s, v_num=ault, train_acc_asr=30
# Epoch 1: 100%|█| 1119/1119 [11:28<00:00,  1.63it/s, v_num=ault, train_acc_asr=38
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:01<00:43,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:02<00:40,  1.14s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:03<00:37,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:04<00:42,  1.25s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:06<00:41,  1.25s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:07<00:40,  1.27s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:08<00:38,  1.26s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:10<00:38,  1.28s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:11<00:36,  1.27s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:12<00:36,  1.29s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:14<00:34,  1.28s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:15<00:34,  1.31s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:17<00:33,  1.34s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:18<00:32,  1.34s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:20<00:30,  1.35s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:21<00:29,  1.34s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:23<00:29,  1.40s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:25<00:28,  1.40s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:26<00:26,  1.40s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:27<00:25,  1.39s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:29<00:23,  1.40s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:30<00:22,  1.41s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:32<00:21,  1.40s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:33<00:19,  1.40s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:35<00:18,  1.41s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:37<00:17,  1.42s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:38<00:15,  1.42s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:39<00:14,  1.41s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:40<00:12,  1.41s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:42<00:11,  1.40s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:42<00:09,  1.38s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:45<00:08,  1.41s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:46<00:07,  1.42s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:48<00:05,  1.42s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:50<00:04,  1.44s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:51<00:02,  1.44s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:53<00:01,  1.44s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:54<00:00,  1.44s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(31.3735, device='cuda:0')
# val_wer_epoch tensor(11.0200, device='cuda:0')
# val_speech_nll_loss_epoch tensor(3.5727, device='cuda:0')
# val_speech_acc_epoch tensor(40.8730, device='cuda:0')
# val_asr_nll_loss_epoch tensor(3.9145, device='cuda:0')
# val_asr_acc_epoch tensor(36.9478, device='cuda:0')
# val_text_nll_loss_epoch tensor(1.2006, device='cuda:0')
# val_text_acc_epoch tensor(70.8333, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(3.0223, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(3.7553, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(5.1115, device='cuda:0')
# val_mix_speech_acc_epoch tensor(42.4603, device='cuda:0')
# val_mix_asr_acc_epoch tensor(36.5462, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(26.0274, device='cuda:0')
# val_guide_loss_epoch tensor(3.6620, device='cuda:0')
# val_reg_loss_epoch tensor(0.3833, device='cuda:0')
# Epoch 1: 100%|█| 1119/1119 [12:23<00:00,  1.51it/s, v_num=ault, train_acc_asr=38
# Epoch 2: 100%|█| 1119/1119 [11:37<00:00,  1.60it/s, v_num=ault, train_acc_asr=57
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:01<00:50,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:02<00:45,  1.25s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:03<00:41,  1.18s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:06<00:54,  1.61s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:07<00:49,  1.50s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:08<00:45,  1.43s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:09<00:43,  1.40s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:11<00:42,  1.41s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:12<00:39,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:13<00:37,  1.35s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:14<00:35,  1.33s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:16<00:34,  1.34s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:17<00:33,  1.36s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:21<00:36,  1.52s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:22<00:34,  1.49s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:23<00:32,  1.49s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:26<00:32,  1.53s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:27<00:30,  1.54s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:28<00:28,  1.52s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:30<00:27,  1.51s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:32<00:26,  1.55s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:33<00:24,  1.54s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:35<00:23,  1.54s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:37<00:22,  1.58s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:39<00:20,  1.56s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:40<00:18,  1.57s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:42<00:17,  1.56s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:45<00:16,  1.63s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:46<00:14,  1.62s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:48<00:12,  1.60s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:48<00:11,  1.58s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:51<00:09,  1.62s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:54<00:08,  1.66s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:56<00:06,  1.65s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:58<00:05,  1.67s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [01:02<00:03,  1.73s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [01:03<00:01,  1.72s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [01:04<00:00,  1.70s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(32.4786, device='cuda:0')
# val_wer_epoch tensor(10.8000, device='cuda:0')
# val_speech_nll_loss_epoch tensor(3.3445, device='cuda:0')
# val_speech_acc_epoch tensor(43.6508, device='cuda:0')
# val_asr_nll_loss_epoch tensor(3.7513, device='cuda:0')
# val_asr_acc_epoch tensor(38.1526, device='cuda:0')
# val_text_nll_loss_epoch tensor(1.1605, device='cuda:0')
# val_text_acc_epoch tensor(72.6190, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(2.7295, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(3.3476, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(4.7765, device='cuda:0')
# val_mix_speech_acc_epoch tensor(47.4206, device='cuda:0')
# val_mix_asr_acc_epoch tensor(41.9679, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(24.4444, device='cuda:0')
# val_guide_loss_epoch tensor(3.4024, device='cuda:0')
# val_reg_loss_epoch tensor(0.3631, device='cuda:0')
# Epoch 2: 100%|█| 1119/1119 [12:42<00:00,  1.47it/s, v_num=ault, train_acc_asr=57
# Epoch 3: 100%|█| 1119/1119 [11:36<00:00,  1.61it/s, v_num=ault, train_acc_asr=55
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:01<00:38,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:02<00:37,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:03<00:35,  1.00s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:06<00:57,  1.69s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:07<00:51,  1.55s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:09<00:49,  1.54s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:10<00:48,  1.55s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:12<00:46,  1.54s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:13<00:43,  1.50s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:14<00:41,  1.48s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:16<00:39,  1.47s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:17<00:37,  1.46s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:19<00:36,  1.47s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:21<00:36,  1.53s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:22<00:34,  1.50s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:25<00:34,  1.57s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:27<00:33,  1.60s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:28<00:31,  1.59s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:29<00:29,  1.57s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:30<00:27,  1.54s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:32<00:26,  1.54s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:33<00:24,  1.53s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:34<00:22,  1.50s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:36<00:21,  1.51s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:37<00:19,  1.50s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:39<00:18,  1.51s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:40<00:16,  1.50s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:41<00:14,  1.49s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:42<00:13,  1.48s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:43<00:11,  1.46s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:44<00:10,  1.44s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:47<00:08,  1.49s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:50<00:07,  1.54s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:52<00:06,  1.53s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:55<00:04,  1.58s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:58<00:03,  1.64s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [01:00<00:01,  1.62s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [01:01<00:00,  1.61s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(34.2361, device='cuda:0')
# val_wer_epoch tensor(10.4600, device='cuda:0')
# val_speech_nll_loss_epoch tensor(3.1519, device='cuda:0')
# val_speech_acc_epoch tensor(44.2460, device='cuda:0')
# val_asr_nll_loss_epoch tensor(3.6052, device='cuda:0')
# val_asr_acc_epoch tensor(40.7631, device='cuda:0')
# val_text_nll_loss_epoch tensor(1.1493, device='cuda:0')
# val_text_acc_epoch tensor(73.2143, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(2.6447, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(3.1639, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(4.4029, device='cuda:0')
# val_mix_speech_acc_epoch tensor(48.0159, device='cuda:0')
# val_mix_asr_acc_epoch tensor(42.5703, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(26.4368, device='cuda:0')
# val_guide_loss_epoch tensor(3.1770, device='cuda:0')
# val_reg_loss_epoch tensor(0.3477, device='cuda:0')
# Epoch 3: 100%|█| 1119/1119 [12:37<00:00,  1.48it/s, v_num=ault, train_acc_asr=55
# Epoch 4: 100%|█| 1119/1119 [11:36<00:00,  1.61it/s, v_num=ault, train_acc_asr=33
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:01<00:44,  1.21s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:02<00:43,  1.21s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:03<00:40,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:05<00:49,  1.47s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:06<00:46,  1.40s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:08<00:45,  1.41s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:09<00:44,  1.42s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:11<00:42,  1.43s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:13<00:41,  1.45s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:14<00:39,  1.42s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:15<00:37,  1.41s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:17<00:37,  1.43s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:18<00:36,  1.46s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:20<00:34,  1.44s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:21<00:32,  1.43s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:22<00:31,  1.42s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:25<00:31,  1.48s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:26<00:29,  1.48s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:27<00:27,  1.47s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:29<00:26,  1.46s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:30<00:24,  1.45s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:32<00:23,  1.47s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:33<00:21,  1.44s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:34<00:20,  1.45s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:36<00:18,  1.44s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:37<00:17,  1.45s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:38<00:15,  1.44s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:39<00:14,  1.43s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:41<00:12,  1.42s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:42<00:11,  1.41s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:42<00:09,  1.39s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:45<00:08,  1.42s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:47<00:07,  1.44s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:48<00:05,  1.44s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:51<00:04,  1.48s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:53<00:02,  1.48s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:54<00:01,  1.47s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:55<00:00,  1.46s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(32.7865, device='cuda:0')
# val_wer_epoch tensor(8.9600, device='cuda:0')
# val_speech_nll_loss_epoch tensor(3.0156, device='cuda:0')
# val_speech_acc_epoch tensor(44.8413, device='cuda:0')
# val_asr_nll_loss_epoch tensor(3.5866, device='cuda:0')
# val_asr_acc_epoch tensor(41.3655, device='cuda:0')
# val_text_nll_loss_epoch tensor(1.1723, device='cuda:0')
# val_text_acc_epoch tensor(72.0238, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(2.5485, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(3.0265, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(3.9422, device='cuda:0')
# val_mix_speech_acc_epoch tensor(49.4048, device='cuda:0')
# val_mix_asr_acc_epoch tensor(45.1807, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(31.3253, device='cuda:0')
# val_guide_loss_epoch tensor(3.0173, device='cuda:0')
# val_reg_loss_epoch tensor(0.3297, device='cuda:0')
# Epoch 4: 100%|█| 1119/1119 [12:33<00:00,  1.49it/s, v_num=ault, train_acc_asr=33
# Epoch 5: 100%|█| 1119/1119 [11:36<00:00,  1.61it/s, v_num=ault, train_acc_asr=50
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:01<00:39,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:02<00:37,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:03<00:35,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:05<00:43,  1.29s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:06<00:41,  1.25s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:07<00:39,  1.22s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:08<00:37,  1.21s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:09<00:36,  1.22s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:10<00:35,  1.22s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:12<00:33,  1.20s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:13<00:32,  1.20s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:14<00:31,  1.22s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:16<00:31,  1.26s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:17<00:30,  1.27s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:18<00:28,  1.26s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:19<00:27,  1.25s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:22<00:27,  1.31s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:23<00:26,  1.31s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:24<00:24,  1.30s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:25<00:23,  1.30s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:27<00:22,  1.30s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:28<00:21,  1.31s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:29<00:19,  1.30s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:31<00:18,  1.30s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:32<00:16,  1.30s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:34<00:15,  1.31s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:35<00:14,  1.30s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:36<00:12,  1.30s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:37<00:11,  1.29s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:38<00:10,  1.29s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:39<00:08,  1.27s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:41<00:07,  1.31s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:43<00:06,  1.33s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:45<00:05,  1.33s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:48<00:04,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:49<00:02,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:50<00:01,  1.37s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:51<00:00,  1.36s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(29.8480, device='cuda:0')
# val_wer_epoch tensor(7.7400, device='cuda:0')
# val_speech_nll_loss_epoch tensor(2.9813, device='cuda:0')
# val_speech_acc_epoch tensor(43.6508, device='cuda:0')
# val_asr_nll_loss_epoch tensor(3.5482, device='cuda:0')
# val_asr_acc_epoch tensor(43.9759, device='cuda:0')
# val_text_nll_loss_epoch tensor(1.2212, device='cuda:0')
# val_text_acc_epoch tensor(71.8254, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(2.5175, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(2.9589, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(3.3809, device='cuda:0')
# val_mix_speech_acc_epoch tensor(50.9921, device='cuda:0')
# val_mix_asr_acc_epoch tensor(46.1847, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(38.2022, device='cuda:0')
# val_guide_loss_epoch tensor(2.9703, device='cuda:0')
# val_reg_loss_epoch tensor(0.3187, device='cuda:0')
# Epoch 5: 100%|█| 1119/1119 [12:28<00:00,  1.49it/s, v_num=ault, train_acc_asr=50
# Epoch 6: 100%|█| 1119/1119 [11:17<00:00,  1.65it/s, v_num=ault, train_acc_asr=62
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:00<00:33,  1.11it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:01<00:33,  1.08it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:02<00:32,  1.08it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:04<00:41,  1.22s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:05<00:39,  1.18s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:06<00:36,  1.13s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:07<00:34,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:08<00:33,  1.11s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:10<00:33,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:11<00:32,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:12<00:31,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:13<00:29,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:15<00:30,  1.21s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:16<00:28,  1.20s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:17<00:27,  1.19s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:18<00:26,  1.19s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:20<00:25,  1.23s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:22<00:24,  1.25s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:23<00:23,  1.23s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:24<00:22,  1.23s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:25<00:20,  1.22s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:27<00:19,  1.23s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:27<00:18,  1.22s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:29<00:17,  1.22s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:30<00:15,  1.22s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:32<00:14,  1.23s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:32<00:13,  1.22s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:34<00:12,  1.22s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:35<00:10,  1.21s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:35<00:09,  1.20s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:36<00:08,  1.18s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:38<00:07,  1.20s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:40<00:06,  1.22s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:41<00:04,  1.21s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:43<00:03,  1.23s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:44<00:02,  1.23s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:45<00:01,  1.23s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:46<00:00,  1.22s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(29.7108, device='cuda:0')
# val_wer_epoch tensor(8.1000, device='cuda:0')
# val_speech_nll_loss_epoch tensor(2.8865, device='cuda:0')
# val_speech_acc_epoch tensor(45.8333, device='cuda:0')
# val_asr_nll_loss_epoch tensor(3.5306, device='cuda:0')
# val_asr_acc_epoch tensor(43.9759, device='cuda:0')
# val_text_nll_loss_epoch tensor(1.2733, device='cuda:0')
# val_text_acc_epoch tensor(71.0317, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(2.4638, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(2.9389, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(3.6261, device='cuda:0')
# val_mix_speech_acc_epoch tensor(50.5952, device='cuda:0')
# val_mix_asr_acc_epoch tensor(48.3936, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(40., device='cuda:0')
# val_guide_loss_epoch tensor(2.8548, device='cuda:0')
# val_reg_loss_epoch tensor(0.3058, device='cuda:0')
# Epoch 6: 100%|█| 1119/1119 [12:04<00:00,  1.54it/s, v_num=ault, train_acc_asr=62
# Epoch 7: 100%|█| 1119/1119 [10:37<00:00,  1.76it/s, v_num=ault, train_acc_asr=57
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:00<00:31,  1.18it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:01<00:34,  1.04it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:02<00:32,  1.09it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:04<00:37,  1.11s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:05<00:35,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:06<00:33,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:07<00:33,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:08<00:33,  1.11s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:10<00:32,  1.12s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:11<00:31,  1.11s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:12<00:29,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:13<00:28,  1.11s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:14<00:28,  1.14s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:16<00:27,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:16<00:26,  1.13s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:18<00:24,  1.13s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:19<00:24,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:21<00:23,  1.18s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:22<00:22,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:23<00:21,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:24<00:19,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:25<00:18,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:26<00:17,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:27<00:16,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:29<00:15,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:30<00:14,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:31<00:12,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:32<00:11,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:33<00:10,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:34<00:09,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:35<00:07,  1.13s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:36<00:06,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:38<00:05,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:39<00:04,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:41<00:03,  1.18s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:42<00:02,  1.18s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:43<00:01,  1.18s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:44<00:00,  1.18s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(29.4562, device='cuda:0')
# val_wer_epoch tensor(7.5400, device='cuda:0')
# ...
# Testing DataLoader 0:  11%|██▏                 | 16/150 [00:13<01:54,  1.17it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  11%|██▎                 | 17/150 [00:14<01:53,  1.17it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  12%|██▍                 | 18/150 [00:15<01:55,  1.14it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  13%|██▌                 | 19/150 [00:16<01:54,  1.14it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  13%|██▋                 | 20/150 [00:17<01:54,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  14%|██▊                 | 21/150 [00:18<01:51,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  15%|██▉                 | 22/150 [00:18<01:49,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  15%|███                 | 23/150 [00:20<01:50,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  16%|███▏                | 24/150 [00:20<01:50,  1.14it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  17%|███▎                | 25/150 [00:21<01:49,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  17%|███▍                | 26/150 [00:22<01:47,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  18%|███▌                | 27/150 [00:23<01:47,  1.14it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  19%|███▋                | 28/150 [00:24<01:45,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  19%|███▊                | 29/150 [00:24<01:43,  1.17it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  20%|████                | 30/150 [00:26<01:44,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  21%|████▏               | 31/150 [00:26<01:42,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  21%|████▎               | 32/150 [00:27<01:41,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  22%|████▍               | 33/150 [00:28<01:40,  1.17it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  23%|████▌               | 34/150 [00:28<01:38,  1.18it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  23%|████▋               | 35/150 [00:29<01:36,  1.19it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  24%|████▊               | 36/150 [00:30<01:37,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  25%|████▉               | 37/150 [00:32<01:38,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  25%|█████               | 38/150 [00:33<01:38,  1.14it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  26%|█████▏              | 39/150 [00:35<01:40,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  27%|█████▎              | 40/150 [00:35<01:38,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  27%|█████▍              | 41/150 [00:36<01:37,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  28%|█████▌              | 42/150 [00:37<01:35,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  29%|█████▋              | 43/150 [00:38<01:34,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  29%|█████▊              | 44/150 [00:38<01:33,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  30%|██████              | 45/150 [00:40<01:33,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  31%|██████▏             | 46/150 [00:41<01:32,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  31%|██████▎             | 47/150 [00:41<01:31,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  32%|██████▍             | 48/150 [00:42<01:31,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  33%|██████▌             | 49/150 [00:43<01:30,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  33%|██████▋             | 50/150 [00:45<01:30,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  34%|██████▊             | 51/150 [00:45<01:29,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  35%|██████▉             | 52/150 [00:46<01:27,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  35%|███████             | 53/150 [00:47<01:26,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  36%|███████▏            | 54/150 [00:47<01:25,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  37%|███████▎            | 55/150 [00:48<01:24,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  37%|███████▍            | 56/150 [00:49<01:23,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  38%|███████▌            | 57/150 [00:49<01:21,  1.14it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  39%|███████▋            | 58/150 [00:50<01:20,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  39%|███████▊            | 59/150 [00:51<01:18,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  40%|████████            | 60/150 [00:52<01:18,  1.14it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  41%|████████▏           | 61/150 [00:52<01:17,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  41%|████████▎           | 62/150 [00:54<01:16,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  42%|████████▍           | 63/150 [00:54<01:15,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  43%|████████▌           | 64/150 [00:55<01:14,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  43%|████████▋           | 65/150 [00:56<01:14,  1.14it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  44%|████████▊           | 66/150 [00:57<01:13,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  45%|████████▉           | 67/150 [00:58<01:12,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  45%|█████████           | 68/150 [00:59<01:11,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  46%|█████████▏          | 69/150 [00:59<01:10,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  47%|█████████▎          | 70/150 [01:00<01:09,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  47%|█████████▍          | 71/150 [01:01<01:08,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  48%|█████████▌          | 72/150 [01:02<01:07,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  49%|█████████▋          | 73/150 [01:02<01:06,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  49%|█████████▊          | 74/150 [01:03<01:05,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  50%|██████████          | 75/150 [01:04<01:04,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  51%|██████████▏         | 76/150 [01:05<01:03,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  51%|██████████▎         | 77/150 [01:06<01:02,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  52%|██████████▍         | 78/150 [01:07<01:02,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  53%|██████████▌         | 79/150 [01:08<01:01,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  53%|██████████▋         | 80/150 [01:09<01:00,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  54%|██████████▊         | 81/150 [01:09<00:59,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  55%|██████████▉         | 82/150 [01:10<00:58,  1.16it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  55%|███████████         | 83/150 [01:12<00:58,  1.15it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  56%|███████████▏        | 84/150 [01:13<00:57,  1.14it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  57%|███████████▎        | 85/150 [01:14<00:57,  1.14it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  57%|███████████▍        | 86/150 [01:15<00:56,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  58%|███████████▌        | 87/150 [01:16<00:55,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  59%|███████████▋        | 88/150 [01:19<00:55,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  59%|███████████▊        | 89/150 [01:19<00:54,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  60%|████████████        | 90/150 [01:20<00:53,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  61%|████████████▏       | 91/150 [01:21<00:53,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  61%|████████████▎       | 92/150 [01:22<00:52,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  62%|████████████▍       | 93/150 [01:24<00:51,  1.10it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  63%|████████████▌       | 94/150 [01:25<00:50,  1.10it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  63%|████████████▋       | 95/150 [01:26<00:49,  1.10it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  64%|████████████▊       | 96/150 [01:26<00:48,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  65%|████████████▉       | 97/150 [01:27<00:47,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  65%|█████████████       | 98/150 [01:28<00:46,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  66%|█████████████▏      | 99/150 [01:29<00:45,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  67%|████████████▋      | 100/150 [01:29<00:44,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  67%|████████████▊      | 101/150 [01:30<00:44,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  68%|████████████▉      | 102/150 [01:31<00:43,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  69%|█████████████      | 103/150 [01:32<00:42,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  69%|█████████████▏     | 104/150 [01:34<00:41,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  70%|█████████████▎     | 105/150 [01:34<00:40,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  71%|█████████████▍     | 106/150 [01:35<00:39,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  71%|█████████████▌     | 107/150 [01:36<00:38,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  72%|█████████████▋     | 108/150 [01:36<00:37,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  73%|█████████████▊     | 109/150 [01:37<00:36,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  73%|█████████████▉     | 110/150 [01:38<00:35,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  74%|██████████████     | 111/150 [01:39<00:34,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  75%|██████████████▏    | 112/150 [01:40<00:33,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  75%|██████████████▎    | 113/150 [01:40<00:33,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  76%|██████████████▍    | 114/150 [01:41<00:32,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  77%|██████████████▌    | 115/150 [01:42<00:31,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  77%|██████████████▋    | 116/150 [01:43<00:30,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  78%|██████████████▊    | 117/150 [01:43<00:29,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  79%|██████████████▉    | 118/150 [01:44<00:28,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  79%|███████████████    | 119/150 [01:46<00:27,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  80%|███████████████▏   | 120/150 [01:47<00:26,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  81%|███████████████▎   | 121/150 [01:48<00:26,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  81%|███████████████▍   | 122/150 [01:49<00:25,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  82%|███████████████▌   | 123/150 [01:50<00:24,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  83%|███████████████▋   | 124/150 [01:51<00:23,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  83%|███████████████▊   | 125/150 [01:52<00:22,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  84%|███████████████▉   | 126/150 [01:53<00:21,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  85%|████████████████   | 127/150 [01:54<00:20,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  85%|████████████████▏  | 128/150 [01:55<00:19,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  86%|████████████████▎  | 129/150 [01:56<00:18,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  87%|████████████████▍  | 130/150 [01:57<00:18,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  87%|████████████████▌  | 131/150 [01:57<00:17,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  88%|████████████████▋  | 132/150 [01:58<00:16,  1.11it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  89%|████████████████▊  | 133/150 [01:59<00:15,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  89%|████████████████▉  | 134/150 [02:00<00:14,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  90%|█████████████████  | 135/150 [02:00<00:13,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  91%|█████████████████▏ | 136/150 [02:01<00:12,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  91%|█████████████████▎ | 137/150 [02:02<00:11,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  92%|█████████████████▍ | 138/150 [02:03<00:10,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  93%|█████████████████▌ | 139/150 [02:03<00:09,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  93%|█████████████████▋ | 140/150 [02:04<00:08,  1.12it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  94%|█████████████████▊ | 141/150 [02:05<00:07,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  95%|█████████████████▉ | 142/150 [02:05<00:07,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  95%|██████████████████ | 143/150 [02:06<00:06,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  96%|██████████████████▏| 144/150 [02:07<00:05,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  97%|██████████████████▎| 145/150 [02:08<00:04,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  97%|██████████████████▍| 146/150 [02:09<00:03,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  98%|██████████████████▌| 147/150 [02:10<00:02,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  99%|██████████████████▋| 148/150 [02:11<00:01,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  99%|██████████████████▊| 149/150 [02:11<00:00,  1.13it/s]warning: dataloader_idx is None
# Testing DataLoader 0: 100%|███████████████████| 150/150 [02:12<00:00,  1.13it/s]test_bleu_spch_epoch tensor(2.1436, device='cuda:0')
# test_bleu_text_epoch tensor(22.9629, device='cuda:0')
# test_wer_epoch tensor(5.2195, device='cuda:0')
# Testing DataLoader 0: 100%|███████████████████| 150/150 [02:12<00:00,  1.13it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │     test_bleu_spch_0      │    2.1435606479644775     │
# │   test_bleu_spch_epoch    │    2.1435606479644775     │
# │     test_bleu_text_0      │    22.962913513183594     │
# │   test_bleu_text_epoch    │    22.962913513183594     │
# │        test_wer_0         │     5.219511985778809     │
# │      test_wer_epoch       │     5.219511985778809     │
# └───────────────────────────┴───────────────────────────┘

# %% [markdown]
# # Visualize

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
import os
import matplotlib.pyplot as plt

# %%
# %pip install tensorboard -qq
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install matplotlib -qq

# %%
# %load_ext tensorboard
# %tensorboard --logdir /kaggle/working/comsl_ja_cy_id/output/comsl_ja2en/logs/ComST/default

# %%
import os

for file in os.listdir("/kaggle/working/comsl_ja_cy_id/output/comsl_ja2en/logs/ComST/default"):
    print(file)
# Out:
# events.out.tfevents.1748828774.5b6844db7a6f.133.0
# events.out.tfevents.1748836273.5b6844db7a6f.133.1
# hparams.yaml

# %% [markdown]
# ## train and validation

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
import os

log_dir = "/kaggle/working/comsl_ja_cy_id/output/comsl_ja2en/logs/ComST/default"
# Chọn file events lớn nhất/thường là mới nhất
event_files = [f for f in os.listdir(log_dir) if f.startswith('events.out.tfevents')]
event_path = os.path.join(log_dir, sorted(event_files)[0])

print(event_path)

event_acc = EventAccumulator(event_path)
event_acc.Reload()

print("Tất cả các scalar tag:")
print(event_acc.Tags()['scalars'])
# Out:
# /kaggle/working/comsl_ja_cy_id/output/comsl_ja2en/logs/ComST/default/events.out.tfevents.1748828774.5b6844db7a6f.133.0
# 2025-06-02 03:51:58.332251: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748836318.354626      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748836318.361423      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Tất cả các scalar tag:
# ['lr-AdamW/pg1', 'lr-AdamW/pg2', 'train_acc_asr', 'train_nll_loss_asr', 'train_acc_text_translate', 'train_nll_loss_text_translate', 'train_acc_speech_translate', 'train_nll_loss_speech_translate', 'train_acc_mix_speech_translate', 'train_nll_loss_mix_speech_translate', 'train_acc_mix_asr', 'train_nll_loss_mix_asr', 'train_acc_mix_mlm', 'train_nll_loss_mix_mlm', 'train_guide_loss', 'train_reg_loss', 'epoch', 'val_bleu_spch_epoch', 'val_bleu_text_epoch', 'val_wer_epoch', 'val_speech_nll_loss_epoch', 'val_speech_acc_epoch', 'val_asr_nll_loss_epoch', 'val_asr_acc_epoch', 'val_text_nll_loss_epoch', 'val_text_acc_epoch', 'val_mix_speech_nll_loss_epoch', 'val_mix_asr_nll_loss_epoch', 'val_mix_mlm_nll_loss_epoch', 'val_mix_speech_acc_epoch', 'val_mix_asr_acc_epoch', 'val_mix_mlm_acc_epoch', 'val_guide_loss_epoch', 'val_reg_loss_epoch']

# %%
train_acc = event_acc.Scalars('train_acc_speech_translate')

# %%
import numpy as np
import matplotlib.pyplot as plt

train_acc = event_acc.Scalars('train_acc_speech_translate')

steps = np.array([e.step for e in train_acc])
values = np.array([e.value for e in train_acc])

num_epochs = 10
total_steps = 3000
steps_per_epoch = total_steps // num_epochs  

start_step = steps[0] 

epoch_ids = ((steps - start_step) // steps_per_epoch).astype(int)

epoch_acc_dict = {}
for epoch in range(num_epochs):
    epoch_acc = values[epoch_ids == epoch]
    if len(epoch_acc) > 0:
        epoch_acc_dict[epoch + 1] = epoch_acc.mean()
    else:
        epoch_acc_dict[epoch + 1] = np.nan

epochs = np.arange(1, num_epochs + 1)
epoch_accs = np.array([epoch_acc_dict[e] for e in epochs])

# Plot
plt.figure(figsize=(8, 6))
plt.plot(epochs, epoch_accs, marker='o')
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("Train Accuracy (%)")
plt.title("Train Accuracy per Epoch")
plt.grid(True)
plt.show()

# %%
train_loss = event_acc.Scalars('train_nll_loss_speech_translate')

steps = np.array([e.step for e in train_loss])
values = np.array([e.value for e in train_loss])

num_epochs = 10
total_steps = 3000
steps_per_epoch = total_steps // num_epochs  

start_step = steps[0] 

epoch_ids = ((steps - start_step) // steps_per_epoch).astype(int)

epoch_acc_dict = {}
for epoch in range(num_epochs):
    epoch_acc = values[epoch_ids == epoch]
    if len(epoch_acc) > 0:
        epoch_acc_dict[epoch + 1] = epoch_acc.mean()
    else:
        epoch_acc_dict[epoch + 1] = np.nan

epochs = np.arange(1, num_epochs + 1)
epoch_accs = np.array([epoch_acc_dict[e] for e in epochs])

# Plot
plt.figure(figsize=(8, 6))
plt.plot(epochs, epoch_accs, marker='o')
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("Train Accuracy (%)")
plt.title("Train Accuracy per Epoch")
plt.grid(True)
plt.show()

# %%
val_acc = event_acc.Scalars('val_speech_acc_epoch')

steps = np.array([e.step for e in val_acc])
values = np.array([e.value for e in val_acc])

num_epochs = 10
total_steps = 3000
steps_per_epoch = total_steps // num_epochs  

start_step = steps[0] 

epoch_ids = ((steps - start_step) // steps_per_epoch).astype(int)

epoch_acc_dict = {}
for epoch in range(num_epochs):
    epoch_acc = values[epoch_ids == epoch]
    if len(epoch_acc) > 0:
        epoch_acc_dict[epoch + 1] = epoch_acc.mean()
    else:
        epoch_acc_dict[epoch + 1] = np.nan

epochs = np.arange(1, num_epochs + 1)
epoch_accs = np.array([epoch_acc_dict[e] for e in epochs])

# Plot
plt.figure(figsize=(8, 6))
plt.plot(epochs, epoch_accs, marker='o')
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("Train Accuracy (%)")
plt.title("Train Accuracy per Epoch")
plt.grid(True)
plt.show()

# %%
val_loss = event_acc.Scalars('val_speech_nll_loss_epoch')

steps = np.array([e.step for e in val_loss])
values = np.array([e.value for e in val_loss])

num_epochs = 10
total_steps = 3000
steps_per_epoch = total_steps // num_epochs  

start_step = steps[0] 

epoch_ids = ((steps - start_step) // steps_per_epoch).astype(int)

epoch_acc_dict = {}
for epoch in range(num_epochs):
    epoch_acc = values[epoch_ids == epoch]
    if len(epoch_acc) > 0:
        epoch_acc_dict[epoch + 1] = epoch_acc.mean()
    else:
        epoch_acc_dict[epoch + 1] = np.nan

epochs = np.arange(1, num_epochs + 1)
epoch_accs = np.array([epoch_acc_dict[e] for e in epochs])

# Plot
plt.figure(figsize=(8, 6))
plt.plot(epochs, epoch_accs, marker='o')
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("Train Accuracy (%)")
plt.title("Train Accuracy per Epoch")
plt.grid(True)
plt.show()

# %% [markdown]
# # test

# %%
test_events = [f for f in os.listdir(log_dir) if f.startswith('events.out')]
test_events = os.path.join(log_dir, sorted(test_events)[-1])

print(test_events)

test_events = EventAccumulator(event_path)
test_events.Reload()

print("Tất cả các scalar tag:")
print(test_events.Tags()['scalars'])
# Out:
# /kaggle/working/comsl_ja_cy_id/output/comsl_ja2en/logs/ComST/default/events.out.tfevents.1748836273.5b6844db7a6f.133.1
# Tất cả các scalar tag:
# ['lr-AdamW/pg1', 'lr-AdamW/pg2', 'train_acc_asr', 'train_nll_loss_asr', 'train_acc_text_translate', 'train_nll_loss_text_translate', 'train_acc_speech_translate', 'train_nll_loss_speech_translate', 'train_acc_mix_speech_translate', 'train_nll_loss_mix_speech_translate', 'train_acc_mix_asr', 'train_nll_loss_mix_asr', 'train_acc_mix_mlm', 'train_nll_loss_mix_mlm', 'train_guide_loss', 'train_reg_loss', 'epoch', 'val_bleu_spch_epoch', 'val_bleu_text_epoch', 'val_wer_epoch', 'val_speech_nll_loss_epoch', 'val_speech_acc_epoch', 'val_asr_nll_loss_epoch', 'val_asr_acc_epoch', 'val_text_nll_loss_epoch', 'val_text_acc_epoch', 'val_mix_speech_nll_loss_epoch', 'val_mix_asr_nll_loss_epoch', 'val_mix_mlm_nll_loss_epoch', 'val_mix_speech_acc_epoch', 'val_mix_asr_acc_epoch', 'val_mix_mlm_acc_epoch', 'val_guide_loss_epoch', 'val_reg_loss_epoch']
