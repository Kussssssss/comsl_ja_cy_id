# %%
# !git clone https://github.com/Kussssssss/comsl_ja_cy_id
# %cd comsl_ja_cy_id
# Out:
# Cloning into 'comsl_ja_cy_id'...
# remote: Enumerating objects: 167, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 167 (delta 58), reused 154 (delta 46), pack-reused 0 (from 0)
# Receiving objects: 100% (167/167), 7.68 MiB | 19.45 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# /kaggle/working/comsl_ja_cy_id

# %% [markdown]
# # Install

# %%
# !pip install numpy==1.26.4 --force-reinstall -qq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 91.8 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.2 which is incompatible.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.1 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 1.42.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pandas-gbq 0.28.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.

# %%
# !pip install transformers==4.29.1 pytorch_lightning==2.0.2 deepspeed==0.9.2 ffmpeg-python more_itertools==9.1.0 PyYAML==6.0 regex==2022.10.31 sacrebleu==2.3.1 torchmetrics==0.11.4 tqdm==4.64.0 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.3/779.3 kB 36.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 104.4 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.0/719.0 kB 42.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.9/757.9 kB 43.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.1/781.1 kB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 38.0 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 103.6 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.1 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.8 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 3.5 MB/s eta 0:00:00
#   Building wheel for deepspeed (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sigstore 3.6.2 requires pydantic<3,>=2, but you have pydantic 1.10.22 which is incompatible.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# datasets 3.6.0 requires tqdm>=4.66.3, but you have tqdm 4.64.0 which is incompatible.
# sigstore-rekor-types 0.0.18 requires pydantic[email]<3,>=2, but you have pydantic 1.10.22 which is incompatible.
# ydata-profiling 4.16.1 requires pydantic>=2, but you have pydantic 1.10.22 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.64.0 which is incompatible.
# kaggle-environments 1.16.11 requires transformers>=4.33.1, but you have transformers 4.29.1 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.9.1 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# dopamine-rl 4.1.2 requires tqdm>=4.64.1, but you have tqdm 4.64.0 which is incompatible.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.29.1 which is incompatible.
# langchain-core 0.3.50 requires packaging<25,>=23.2, but you have packaging 25.0 which is incompatible.
# langchain-core 0.3.50 requires pydantic<3.0.0,>=2.5.2; python_full_version < "3.12.4", but you have pydantic 1.10.22 which is incompatible.
# langchain 0.3.22 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.22 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 44.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.0.0 which is incompatible.
# google-genai 1.9.0 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.22 which is incompatible.
# albumentations 2.0.5 requires pydantic>=2.9.2, but you have pydantic 1.10.22 which is incompatible.

# %%
import warnings
warnings.filterwarnings("ignore", message="dataloader_idx is None")
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Create forder for logs

# %%
import os

output_path = "/kaggle/working/comsl_ja_cy_id/output/comsl_id2en/logs"
os.makedirs(output_path, exist_ok=True)
print(f"Đã tạo thư mục: {output_path}")
# Out:
# Đã tạo thư mục: /kaggle/working/comsl_ja_cy_id/output/comsl_id2en/logs

# %% [markdown]
# # Remove logs (in case of re-running)

# %%
import os
import glob

log_dir = '/kaggle/working/comsl_ja_cy_id/output/comsl_id2en/logs'

# Xóa tất cả file trong thư mục log_dir
for file_path in glob.glob(os.path.join(log_dir, '*')):
    try:
        os.remove(file_path)
    except IsADirectoryError:
        pass

# %% [markdown]
# # Execute

# %%
# !python /kaggle/working/comsl_ja_cy_id/run.py --config comsl.yaml
# Out:
# 2025-06-01 13:27:01.764908: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748784421.953444     171 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748784422.007693     171 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/deepspeed/runtime/zero/linear.py:47: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @autocast_custom_fwd
# /usr/local/lib/python3.11/dist-packages/deepspeed/runtime/zero/linear.py:66: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @autocast_custom_bwd
# Loaded 1200 indonesian to english data pairs.
# Loaded 150 indonesian to english data pairs.
# Loaded 150 indonesian to english data pairs.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json: 100%|███████████████████| 529/529 [00:00<00:00, 2.93MB/s]
# sentencepiece.bpe.model: 100%|█████████████| 5.07M/5.07M [00:01<00:00, 4.38MB/s]
# special_tokens_map.json: 100%|█████████████████| 649/649 [00:00<00:00, 3.88MB/s]
# config.json: 100%|█████████████████████████| 1.43k/1.43k [00:00<00:00, 7.88MB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# model.safetensors: 100%|████████████████████| 2.44G/2.44G [00:14<00:00, 165MB/s]
# generation_config.json: 100%|██████████████████| 261/261 [00:00<00:00, 1.72MB/s]
# 100%|█████████████████████████████████████| 72.1M/72.1M [00:01<00:00, 43.5MiB/s]
# /usr/local/lib/python3.11/dist-packages/lightning_fabric/connector.py:562: UserWarning: 16 is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
#   rank_zero_warn(
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/plugins/precision/amp.py:47: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/trainer/connectors/checkpoint_connector.py:189: UserWarning: .fit(ckpt_path="last") is set, but there is no last checkpoint available. No checkpoint will be loaded.
#   rank_zero_warn(
# Sanity Checking DataLoader 0:   0%|                       | 0/2 [00:00<?, ?it/s]warning: dataloader_idx is None
# Sanity Checking DataLoader 0:  50%|███████▌       | 1/2 [00:02<00:02,  2.28s/it]warning: dataloader_idx is None
# Sanity Checking DataLoader 0: 100%|███████████████| 2/2 [00:03<00:00,  1.99s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(0., device='cuda:0')
# val_wer_epoch tensor(2.7000, device='cuda:0')
# val_speech_nll_loss_epoch tensor(10.1252, device='cuda:0')
# val_speech_acc_epoch tensor(13.3333, device='cuda:0')
# val_asr_nll_loss_epoch tensor(7.9706, device='cuda:0')
# val_asr_acc_epoch tensor(13.3333, device='cuda:0')
# val_text_nll_loss_epoch tensor(1.2308, device='cuda:0')
# val_text_acc_epoch tensor(53.3333, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(7.6031, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(7.6782, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(7.8407, device='cuda:0')
# val_mix_speech_acc_epoch tensor(13.3333, device='cuda:0')
# val_mix_asr_acc_epoch tensor(13.3333, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(0., device='cuda:0')
# val_guide_loss_epoch tensor(10.2055, device='cuda:0')
# val_reg_loss_epoch tensor(0.3804, device='cuda:0')
# Epoch 0: 100%|█| 1200/1200 [11:11<00:00,  1.79it/s, v_num=ault, train_acc_asr=28
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:00<00:36,  1.02it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:01<00:35,  1.01it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:03<00:36,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:04<00:34,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:05<00:33,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:05<00:31,  1.02it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:07<00:32,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:08<00:31,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:09<00:30,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:10<00:29,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:11<00:27,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:12<00:27,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:13<00:26,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:14<00:25,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:15<00:23,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:16<00:23,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:17<00:21,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:18<00:20,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:19<00:19,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:21<00:18,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:22<00:18,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:23<00:16,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:24<00:15,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:25<00:14,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:26<00:13,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:27<00:12,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:28<00:11,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:29<00:10,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:30<00:09,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:31<00:08,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:32<00:07,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:34<00:06,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:35<00:05,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:36<00:04,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:37<00:03,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:38<00:02,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:39<00:01,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:40<00:00,  1.07s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(45.0576, device='cuda:0')
# val_wer_epoch tensor(1.3294, device='cuda:0')
# val_speech_nll_loss_epoch tensor(4.0060, device='cuda:0')
# val_speech_acc_epoch tensor(39.5577, device='cuda:0')
# val_asr_nll_loss_epoch tensor(5.8219, device='cuda:0')
# val_asr_acc_epoch tensor(21.6146, device='cuda:0')
# val_text_nll_loss_epoch tensor(0.8094, device='cuda:0')
# val_text_acc_epoch tensor(80.8354, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(3.5501, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(5.8978, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(5.6125, device='cuda:0')
# val_mix_speech_acc_epoch tensor(36.8550, device='cuda:0')
# val_mix_asr_acc_epoch tensor(20.3125, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(20., device='cuda:0')
# val_guide_loss_epoch tensor(4.1412, device='cuda:0')
# val_reg_loss_epoch tensor(0.4024, device='cuda:0')
# Epoch 0: 100%|█| 1200/1200 [11:52<00:00,  1.68it/s, v_num=ault, train_acc_asr=28
# Epoch 1: 100%|█| 1200/1200 [11:28<00:00,  1.74it/s, v_num=ault, train_acc_asr=40
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:00<00:33,  1.12it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:02<00:37,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:03<00:38,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:04<00:36,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:05<00:34,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:06<00:32,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:07<00:33,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:08<00:32,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:09<00:31,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:11<00:31,  1.12s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:12<00:29,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:13<00:28,  1.11s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:14<00:27,  1.11s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:15<00:26,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:16<00:24,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:17<00:24,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:18<00:22,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:19<00:21,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:20<00:20,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:21<00:19,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:23<00:18,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:24<00:17,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:25<00:16,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:26<00:15,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:27<00:14,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:28<00:13,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:29<00:11,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:30<00:10,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:31<00:09,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:32<00:08,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:33<00:07,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:34<00:06,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:35<00:05,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:36<00:04,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:37<00:03,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:38<00:02,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:39<00:01,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:40<00:00,  1.07s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(55.7793, device='cuda:0')
# val_wer_epoch tensor(1.2738, device='cuda:0')
# val_speech_nll_loss_epoch tensor(3.5090, device='cuda:0')
# val_speech_acc_epoch tensor(42.2604, device='cuda:0')
# val_asr_nll_loss_epoch tensor(4.4799, device='cuda:0')
# val_asr_acc_epoch tensor(31.7708, device='cuda:0')
# val_text_nll_loss_epoch tensor(0.6943, device='cuda:0')
# val_text_acc_epoch tensor(81.5725, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(2.9762, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(4.3673, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(5.6017, device='cuda:0')
# val_mix_speech_acc_epoch tensor(43.7346, device='cuda:0')
# val_mix_asr_acc_epoch tensor(33.3333, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(21.6667, device='cuda:0')
# val_guide_loss_epoch tensor(3.6082, device='cuda:0')
# val_reg_loss_epoch tensor(0.3717, device='cuda:0')
# Epoch 1: 100%|█| 1200/1200 [12:09<00:00,  1.64it/s, v_num=ault, train_acc_asr=40
# Epoch 2: 100%|█| 1200/1200 [11:27<00:00,  1.75it/s, v_num=ault, train_acc_asr=42
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:01<00:40,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:02<00:36,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:03<00:38,  1.11s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:04<00:39,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:05<00:37,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:06<00:35,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:08<00:36,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:09<00:35,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:10<00:33,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:11<00:33,  1.19s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:12<00:31,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:14<00:31,  1.19s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:15<00:29,  1.19s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:16<00:28,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:17<00:26,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:18<00:25,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:19<00:24,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:20<00:22,  1.13s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:21<00:21,  1.14s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:23<00:20,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:24<00:19,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:25<00:18,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:26<00:17,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:28<00:16,  1.17s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:29<00:15,  1.19s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:30<00:14,  1.18s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:31<00:12,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:32<00:11,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:33<00:10,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:34<00:09,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:35<00:08,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:37<00:06,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:38<00:05,  1.16s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:39<00:04,  1.15s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:39<00:03,  1.14s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:40<00:02,  1.13s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:41<00:01,  1.13s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:43<00:00,  1.13s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(57.8665, device='cuda:0')
# val_wer_epoch tensor(1.4802, device='cuda:0')
# val_speech_nll_loss_epoch tensor(3.2660, device='cuda:0')
# val_speech_acc_epoch tensor(42.9975, device='cuda:0')
# val_asr_nll_loss_epoch tensor(4.1014, device='cuda:0')
# val_asr_acc_epoch tensor(33.0729, device='cuda:0')
# val_text_nll_loss_epoch tensor(0.6531, device='cuda:0')
# val_text_acc_epoch tensor(82.5553, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(2.5919, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(3.7543, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(5.7858, device='cuda:0')
# val_mix_speech_acc_epoch tensor(48.4029, device='cuda:0')
# val_mix_asr_acc_epoch tensor(38.2812, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(13.3333, device='cuda:0')
# val_guide_loss_epoch tensor(3.3397, device='cuda:0')
# val_reg_loss_epoch tensor(0.3483, device='cuda:0')
# Epoch 2: 100%|█| 1200/1200 [12:10<00:00,  1.64it/s, v_num=ault, train_acc_asr=42
# Epoch 3: 100%|█| 1200/1200 [11:26<00:00,  1.75it/s, v_num=ault, train_acc_asr=28
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:00<00:35,  1.03it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:02<00:36,  1.00s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:03<00:36,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:04<00:36,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:05<00:35,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:06<00:33,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:07<00:33,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:08<00:32,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:09<00:31,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:10<00:30,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:11<00:29,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:13<00:28,  1.11s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:14<00:27,  1.12s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:15<00:26,  1.11s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:16<00:25,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:17<00:24,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:18<00:22,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:19<00:21,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:20<00:20,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:21<00:19,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:23<00:18,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:24<00:17,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:25<00:16,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:26<00:15,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:27<00:14,  1.11s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:28<00:13,  1.10s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:29<00:11,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:30<00:10,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:31<00:09,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:32<00:08,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:33<00:07,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:34<00:06,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:35<00:05,  1.09s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:36<00:04,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:37<00:03,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:38<00:02,  1.07s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:39<00:01,  1.08s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:40<00:00,  1.08s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(61.0069, device='cuda:0')
# val_wer_epoch tensor(1.3254, device='cuda:0')
# val_speech_nll_loss_epoch tensor(3.1531, device='cuda:0')
# val_speech_acc_epoch tensor(42.7518, device='cuda:0')
# val_asr_nll_loss_epoch tensor(4.0332, device='cuda:0')
# val_asr_acc_epoch tensor(35.1562, device='cuda:0')
# val_text_nll_loss_epoch tensor(0.6268, device='cuda:0')
# val_text_acc_epoch tensor(83.0467, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(2.3582, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(3.4313, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(4.9937, device='cuda:0')
# val_mix_speech_acc_epoch tensor(52.5798, device='cuda:0')
# val_mix_asr_acc_epoch tensor(44.0104, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(20., device='cuda:0')
# val_guide_loss_epoch tensor(3.2078, device='cuda:0')
# val_reg_loss_epoch tensor(0.3266, device='cuda:0')
# Epoch 3: 100%|█| 1200/1200 [12:08<00:00,  1.65it/s, v_num=ault, train_acc_asr=28
# Epoch 4: 100%|█| 1200/1200 [11:20<00:00,  1.76it/s, v_num=ault, train_acc_asr=22
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:00<00:30,  1.21it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:01<00:33,  1.09it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:02<00:34,  1.02it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:04<00:34,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:04<00:32,  1.00it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:05<00:30,  1.04it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:06<00:30,  1.00it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:08<00:30,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:08<00:28,  1.00it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:10<00:28,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:11<00:27,  1.00s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:12<00:26,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:13<00:26,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:14<00:24,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:15<00:23,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:16<00:22,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:17<00:21,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:18<00:20,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:19<00:19,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:20<00:18,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:21<00:17,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:22<00:16,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:23<00:15,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:24<00:14,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:25<00:13,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:26<00:12,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:27<00:11,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:28<00:10,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:29<00:09,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:30<00:08,  1.00s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:31<00:07,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:32<00:06,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:33<00:05,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:34<00:04,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:34<00:02,  1.00it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:35<00:01,  1.01it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:36<00:00,  1.01it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:37<00:00,  1.01it/s]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(59.5209, device='cuda:0')
# val_wer_epoch tensor(1.1667, device='cuda:0')
# val_speech_nll_loss_epoch tensor(3.0363, device='cuda:0')
# val_speech_acc_epoch tensor(44.7174, device='cuda:0')
# val_asr_nll_loss_epoch tensor(3.9080, device='cuda:0')
# val_asr_acc_epoch tensor(35.4167, device='cuda:0')
# val_text_nll_loss_epoch tensor(0.6257, device='cuda:0')
# val_text_acc_epoch tensor(84.0295, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(2.1089, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(3.1095, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(4.4836, device='cuda:0')
# val_mix_speech_acc_epoch tensor(55.5283, device='cuda:0')
# val_mix_asr_acc_epoch tensor(48.4375, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(26.3889, device='cuda:0')
# val_guide_loss_epoch tensor(3.0721, device='cuda:0')
# val_reg_loss_epoch tensor(0.3119, device='cuda:0')
# Epoch 4: 100%|█| 1200/1200 [11:58<00:00,  1.67it/s, v_num=ault, train_acc_asr=22
# Epoch 5: 100%|█| 1200/1200 [11:28<00:00,  1.74it/s, v_num=ault, train_acc_asr=40
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:00<00:29,  1.24it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:01<00:31,  1.16it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:02<00:33,  1.03it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:04<00:34,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:05<00:33,  1.00s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:05<00:30,  1.04it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:06<00:30,  1.01it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:08<00:30,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:09<00:29,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:10<00:28,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:11<00:27,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:12<00:26,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:13<00:25,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:14<00:24,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:15<00:23,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:16<00:22,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:17<00:21,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:18<00:20,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:19<00:19,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:20<00:18,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:21<00:17,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:22<00:16,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:23<00:15,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:24<00:14,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:26<00:13,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:27<00:12,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:27<00:11,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:28<00:10,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:29<00:09,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:30<00:08,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:32<00:07,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:33<00:06,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:34<00:05,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:35<00:04,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:35<00:03,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:36<00:02,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:37<00:01,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:38<00:00,  1.02s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(60.7144, device='cuda:0')
# val_wer_epoch tensor(1.0952, device='cuda:0')
# val_speech_nll_loss_epoch tensor(2.8789, device='cuda:0')
# val_speech_acc_epoch tensor(47.9115, device='cuda:0')
# val_asr_nll_loss_epoch tensor(3.8030, device='cuda:0')
# val_asr_acc_epoch tensor(38.0208, device='cuda:0')
# val_text_nll_loss_epoch tensor(0.6095, device='cuda:0')
# val_text_acc_epoch tensor(83.7838, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(2.0429, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(2.9803, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(4.9897, device='cuda:0')
# val_mix_speech_acc_epoch tensor(56.7568, device='cuda:0')
# val_mix_asr_acc_epoch tensor(49.7396, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(22.0588, device='cuda:0')
# val_guide_loss_epoch tensor(2.9103, device='cuda:0')
# val_reg_loss_epoch tensor(0.3014, device='cuda:0')
# Epoch 5: 100%|█| 1200/1200 [12:07<00:00,  1.65it/s, v_num=ault, train_acc_asr=40
# Epoch 6: 100%|█| 1200/1200 [11:33<00:00,  1.73it/s, v_num=ault, train_acc_asr=60
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:00<00:28,  1.31it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:01<00:30,  1.20it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:02<00:33,  1.05it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:03<00:33,  1.02it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:04<00:32,  1.01it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:05<00:30,  1.04it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:06<00:30,  1.01it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:08<00:30,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:08<00:28,  1.00it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:10<00:28,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:11<00:27,  1.00s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:12<00:27,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:13<00:26,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:14<00:24,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:15<00:23,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:16<00:22,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:17<00:21,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:18<00:20,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:19<00:19,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:20<00:18,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:21<00:17,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:22<00:16,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:23<00:15,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:25<00:14,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:26<00:13,  1.06s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:27<00:12,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:28<00:11,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:29<00:10,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:30<00:09,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:31<00:08,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:32<00:07,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:33<00:06,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:34<00:05,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:35<00:04,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:36<00:03,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:37<00:02,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:38<00:01,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:39<00:00,  1.04s/it]val_bleu_spch_epoch tensor(0., device='cuda:0')
# val_bleu_text_epoch tensor(58.4516, device='cuda:0')
# val_wer_epoch tensor(1.0397, device='cuda:0')
# val_speech_nll_loss_epoch tensor(2.7230, device='cuda:0')
# val_speech_acc_epoch tensor(48.8943, device='cuda:0')
# val_asr_nll_loss_epoch tensor(3.6100, device='cuda:0')
# val_asr_acc_epoch tensor(44.5312, device='cuda:0')
# val_text_nll_loss_epoch tensor(0.6470, device='cuda:0')
# val_text_acc_epoch tensor(83.2924, device='cuda:0')
# val_mix_speech_nll_loss_epoch tensor(1.9660, device='cuda:0')
# val_mix_asr_nll_loss_epoch tensor(2.8021, device='cuda:0')
# val_mix_mlm_nll_loss_epoch tensor(4.5697, device='cuda:0')
# val_mix_speech_acc_epoch tensor(59.2138, device='cuda:0')
# val_mix_asr_acc_epoch tensor(52.6042, device='cuda:0')
# val_mix_mlm_acc_epoch tensor(29.8507, device='cuda:0')
# val_guide_loss_epoch tensor(2.7317, device='cuda:0')
# val_reg_loss_epoch tensor(0.2945, device='cuda:0')
# Epoch 6: 100%|█| 1200/1200 [12:13<00:00,  1.64it/s, v_num=ault, train_acc_asr=60
# Epoch 7: 100%|█| 1200/1200 [11:22<00:00,  1.76it/s, v_num=ault, train_acc_asr=77
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/38 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/38 [00:00<?, ?it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   3%|▌                  | 1/38 [00:00<00:28,  1.29it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   5%|█                  | 2/38 [00:01<00:30,  1.18it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:   8%|█▌                 | 3/38 [00:02<00:34,  1.01it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  11%|██                 | 4/38 [00:04<00:35,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  13%|██▌                | 5/38 [00:05<00:33,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  16%|███                | 6/38 [00:05<00:30,  1.03it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  18%|███▌               | 7/38 [00:06<00:30,  1.01it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  21%|████               | 8/38 [00:07<00:29,  1.01it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  24%|████▌              | 9/38 [00:08<00:28,  1.00it/s]warning: dataloader_idx is None
#
# Validation DataLoader 0:  26%|████▋             | 10/38 [00:10<00:28,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  29%|█████▏            | 11/38 [00:11<00:27,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  32%|█████▋            | 12/38 [00:12<00:27,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  34%|██████▏           | 13/38 [00:13<00:26,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  37%|██████▋           | 14/38 [00:14<00:25,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  39%|███████           | 15/38 [00:15<00:23,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  42%|███████▌          | 16/38 [00:16<00:22,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  45%|████████          | 17/38 [00:17<00:21,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  47%|████████▌         | 18/38 [00:18<00:20,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  50%|█████████         | 19/38 [00:19<00:19,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  53%|█████████▍        | 20/38 [00:20<00:18,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  55%|█████████▉        | 21/38 [00:21<00:17,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  58%|██████████▍       | 22/38 [00:22<00:16,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  61%|██████████▉       | 23/38 [00:23<00:15,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  63%|███████████▎      | 24/38 [00:24<00:14,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  66%|███████████▊      | 25/38 [00:26<00:13,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  68%|████████████▎     | 26/38 [00:27<00:12,  1.05s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  71%|████████████▊     | 27/38 [00:27<00:11,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  74%|█████████████▎    | 28/38 [00:28<00:10,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  76%|█████████████▋    | 29/38 [00:30<00:09,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  79%|██████████████▏   | 30/38 [00:30<00:08,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  82%|██████████████▋   | 31/38 [00:31<00:07,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  84%|███████████████▏  | 32/38 [00:33<00:06,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  87%|███████████████▋  | 33/38 [00:34<00:05,  1.04s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  89%|████████████████  | 34/38 [00:35<00:04,  1.03s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  92%|████████████████▌ | 35/38 [00:35<00:03,  1.02s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  95%|█████████████████ | 36/38 [00:36<00:02,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0:  97%|█████████████████▌| 37/38 [00:37<00:01,  1.01s/it]warning: dataloader_idx is None
#
# Validation DataLoader 0: 100%|██████████████████| 38/38 [00:38<00:00,  1.02s/it]val_bleu_spch_epoch tensor(3.3032, device='cuda:0')
# val_bleu_text_epoch tensor(54.4266, device='cuda:0')
# ...
# Testing DataLoader 0:  11%|██▏                 | 16/150 [00:11<01:35,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  11%|██▎                 | 17/150 [00:12<01:34,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  12%|██▍                 | 18/150 [00:13<01:35,  1.38it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  13%|██▌                 | 19/150 [00:13<01:34,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  13%|██▋                 | 20/150 [00:14<01:32,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  14%|██▊                 | 21/150 [00:14<01:31,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  15%|██▉                 | 22/150 [00:15<01:31,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  15%|███                 | 23/150 [00:16<01:30,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  16%|███▏                | 24/150 [00:17<01:29,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  17%|███▎                | 25/150 [00:17<01:28,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  17%|███▍                | 26/150 [00:18<01:28,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  18%|███▌                | 27/150 [00:19<01:26,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  19%|███▋                | 28/150 [00:19<01:26,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  19%|███▊                | 29/150 [00:20<01:25,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  20%|████                | 30/150 [00:21<01:25,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  21%|████▏               | 31/150 [00:22<01:25,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  21%|████▎               | 32/150 [00:22<01:23,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  22%|████▍               | 33/150 [00:23<01:23,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  23%|████▌               | 34/150 [00:24<01:22,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  23%|████▋               | 35/150 [00:25<01:23,  1.37it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  24%|████▊               | 36/150 [00:26<01:22,  1.38it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  25%|████▉               | 37/150 [00:26<01:22,  1.38it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  25%|█████               | 38/150 [00:27<01:20,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  26%|█████▏              | 39/150 [00:27<01:19,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  27%|█████▎              | 40/150 [00:28<01:19,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  27%|█████▍              | 41/150 [00:29<01:18,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  28%|█████▌              | 42/150 [00:30<01:17,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  29%|█████▋              | 43/150 [00:30<01:16,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  29%|█████▊              | 44/150 [00:31<01:15,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  30%|██████              | 45/150 [00:31<01:14,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  31%|██████▏             | 46/150 [00:32<01:13,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  31%|██████▎             | 47/150 [00:32<01:12,  1.43it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  32%|██████▍             | 48/150 [00:33<01:11,  1.43it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  33%|██████▌             | 49/150 [00:34<01:10,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  33%|██████▋             | 50/150 [00:35<01:10,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  34%|██████▊             | 51/150 [00:36<01:09,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  35%|██████▉             | 52/150 [00:36<01:09,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  35%|███████             | 53/150 [00:37<01:08,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  36%|███████▏            | 54/150 [00:37<01:07,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  37%|███████▎            | 55/150 [00:39<01:07,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  37%|███████▍            | 56/150 [00:40<01:07,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  38%|███████▌            | 57/150 [00:40<01:06,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  39%|███████▋            | 58/150 [00:41<01:05,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  39%|███████▊            | 59/150 [00:42<01:05,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  40%|████████            | 60/150 [00:42<01:04,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  41%|████████▏           | 61/150 [00:43<01:04,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  41%|████████▎           | 62/150 [00:44<01:03,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  42%|████████▍           | 63/150 [00:44<01:02,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  43%|████████▌           | 64/150 [00:45<01:01,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  43%|████████▋           | 65/150 [00:46<01:00,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  44%|████████▊           | 66/150 [00:47<01:00,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  45%|████████▉           | 67/150 [00:48<00:59,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  45%|█████████           | 68/150 [00:48<00:58,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  46%|█████████▏          | 69/150 [00:49<00:58,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  47%|█████████▎          | 70/150 [00:50<00:57,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  47%|█████████▍          | 71/150 [00:51<00:56,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  48%|█████████▌          | 72/150 [00:52<00:56,  1.38it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  49%|█████████▋          | 73/150 [00:52<00:55,  1.38it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  49%|█████████▊          | 74/150 [00:53<00:54,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  50%|██████████          | 75/150 [00:54<00:54,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  51%|██████████▏         | 76/150 [00:54<00:53,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  51%|██████████▎         | 77/150 [00:55<00:52,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  52%|██████████▍         | 78/150 [00:56<00:51,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  53%|██████████▌         | 79/150 [00:56<00:50,  1.39it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  53%|██████████▋         | 80/150 [00:57<00:50,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  54%|██████████▊         | 81/150 [00:57<00:49,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  55%|██████████▉         | 82/150 [00:58<00:48,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  55%|███████████         | 83/150 [00:59<00:47,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  56%|███████████▏        | 84/150 [00:59<00:46,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  57%|███████████▎        | 85/150 [01:00<00:46,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  57%|███████████▍        | 86/150 [01:00<00:45,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  58%|███████████▌        | 87/150 [01:01<00:44,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  59%|███████████▋        | 88/150 [01:02<00:44,  1.40it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  59%|███████████▊        | 89/150 [01:03<00:43,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  60%|████████████        | 90/150 [01:03<00:42,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  61%|████████████▏       | 91/150 [01:04<00:41,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  61%|████████████▎       | 92/150 [01:05<00:41,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  62%|████████████▍       | 93/150 [01:05<00:40,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  63%|████████████▌       | 94/150 [01:06<00:39,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  63%|████████████▋       | 95/150 [01:07<00:38,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  64%|████████████▊       | 96/150 [01:08<00:38,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  65%|████████████▉       | 97/150 [01:08<00:37,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  65%|█████████████       | 98/150 [01:09<00:36,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  66%|█████████████▏      | 99/150 [01:10<00:36,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  67%|████████████▋      | 100/150 [01:11<00:35,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  67%|████████████▊      | 101/150 [01:11<00:34,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  68%|████████████▉      | 102/150 [01:12<00:34,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  69%|█████████████      | 103/150 [01:12<00:33,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  69%|█████████████▏     | 104/150 [01:13<00:32,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  70%|█████████████▎     | 105/150 [01:14<00:31,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  71%|█████████████▍     | 106/150 [01:14<00:30,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  71%|█████████████▌     | 107/150 [01:15<00:30,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  72%|█████████████▋     | 108/150 [01:16<00:29,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  73%|█████████████▊     | 109/150 [01:17<00:28,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  73%|█████████████▉     | 110/150 [01:17<00:28,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  74%|██████████████     | 111/150 [01:18<00:27,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  75%|██████████████▏    | 112/150 [01:18<00:26,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  75%|██████████████▎    | 113/150 [01:19<00:26,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  76%|██████████████▍    | 114/150 [01:20<00:25,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  77%|██████████████▌    | 115/150 [01:20<00:24,  1.43it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  77%|██████████████▋    | 116/150 [01:21<00:23,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  78%|██████████████▊    | 117/150 [01:22<00:23,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  79%|██████████████▉    | 118/150 [01:23<00:22,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  79%|███████████████    | 119/150 [01:24<00:21,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  80%|███████████████▏   | 120/150 [01:24<00:21,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  81%|███████████████▎   | 121/150 [01:25<00:20,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  81%|███████████████▍   | 122/150 [01:26<00:19,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  82%|███████████████▌   | 123/150 [01:26<00:19,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  83%|███████████████▋   | 124/150 [01:27<00:18,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  83%|███████████████▊   | 125/150 [01:28<00:17,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  84%|███████████████▉   | 126/150 [01:28<00:16,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  85%|████████████████   | 127/150 [01:29<00:16,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  85%|████████████████▏  | 128/150 [01:30<00:15,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  86%|████████████████▎  | 129/150 [01:31<00:14,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  87%|████████████████▍  | 130/150 [01:32<00:14,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  87%|████████████████▌  | 131/150 [01:32<00:13,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  88%|████████████████▋  | 132/150 [01:33<00:12,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  89%|████████████████▊  | 133/150 [01:34<00:12,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  89%|████████████████▉  | 134/150 [01:34<00:11,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  90%|█████████████████  | 135/150 [01:35<00:10,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  91%|█████████████████▏ | 136/150 [01:36<00:09,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  91%|█████████████████▎ | 137/150 [01:37<00:09,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  92%|█████████████████▍ | 138/150 [01:37<00:08,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  93%|█████████████████▌ | 139/150 [01:38<00:07,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  93%|█████████████████▋ | 140/150 [01:39<00:07,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  94%|█████████████████▊ | 141/150 [01:39<00:06,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  95%|█████████████████▉ | 142/150 [01:40<00:05,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  95%|██████████████████ | 143/150 [01:41<00:04,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  96%|██████████████████▏| 144/150 [01:41<00:04,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  97%|██████████████████▎| 145/150 [01:42<00:03,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  97%|██████████████████▍| 146/150 [01:43<00:02,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  98%|██████████████████▌| 147/150 [01:43<00:02,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  99%|██████████████████▋| 148/150 [01:44<00:01,  1.41it/s]warning: dataloader_idx is None
# Testing DataLoader 0:  99%|██████████████████▊| 149/150 [01:45<00:00,  1.42it/s]warning: dataloader_idx is None
# Testing DataLoader 0: 100%|███████████████████| 150/150 [01:45<00:00,  1.42it/s]test_bleu_spch_epoch tensor(2.4124, device='cuda:0')
# test_bleu_text_epoch tensor(51.3275, device='cuda:0')
# test_wer_epoch tensor(1.0500, device='cuda:0')
# Testing DataLoader 0: 100%|███████████████████| 150/150 [01:45<00:00,  1.42it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │     test_bleu_spch_0      │     2.412397861480713     │
# │   test_bleu_spch_epoch    │     2.412397861480713     │
# │     test_bleu_text_0      │     51.32749557495117     │
# │   test_bleu_text_epoch    │     51.32749557495117     │
# │        test_wer_0         │    1.0499999523162842     │
# │      test_wer_epoch       │    1.0499999523162842     │
# └───────────────────────────┴───────────────────────────┘

# %% [markdown]
# # Visualize

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
import os
import matplotlib.pyplot as plt

# %%
# %pip install tensorboard -qq
import os
os._exit(0)

# %%
# !pip install matplotlib -qq

# %%
# %load_ext tensorboard
# %tensorboard --logdir /kaggle/working/comsl_ja_cy_id/output/comsl_id2en/logs/ComST/default
# Out:
# Reusing TensorBoard on port 6006 (pid 1103), started 0:04:54 ago. (Use '!kill 1103' to kill it.)

# %%
import os

for file in os.listdir("/kaggle/working/comsl_ja_cy_id/output/comsl_id2en/logs/ComST/default"):
    print(file)
# Out:
# events.out.tfevents.1748784483.9ffdbac2db6d.171.0
# events.out.tfevents.1748791931.9ffdbac2db6d.171.1
# hparams.yaml

# %% [markdown]
# ## train and validation

# %%
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
import os

log_dir = "/kaggle/working/comsl_ja_cy_id/output/comsl_id2en/logs/ComST/default"
# Chọn file events lớn nhất/thường là mới nhất
event_files = [f for f in os.listdir(log_dir) if f.startswith('events.out.tfevents')]
event_path = os.path.join(log_dir, sorted(event_files)[0])

print(event_path)

event_acc = EventAccumulator(event_path)
event_acc.Reload()

print("Tất cả các scalar tag:")
print(event_acc.Tags()['scalars'])
# Out:
# /kaggle/working/comsl_ja_cy_id/output/comsl_id2en/logs/ComST/default/events.out.tfevents.1748784483.9ffdbac2db6d.171.0
# 2025-06-01 16:06:17.226708: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748793977.249976    1154 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748793977.256937    1154 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Tất cả các scalar tag:
# ['lr-AdamW/pg1', 'lr-AdamW/pg2', 'train_acc_asr', 'train_nll_loss_asr', 'train_acc_text_translate', 'train_nll_loss_text_translate', 'train_acc_speech_translate', 'train_nll_loss_speech_translate', 'train_acc_mix_speech_translate', 'train_nll_loss_mix_speech_translate', 'train_acc_mix_asr', 'train_nll_loss_mix_asr', 'train_acc_mix_mlm', 'train_nll_loss_mix_mlm', 'train_guide_loss', 'train_reg_loss', 'epoch', 'val_bleu_spch_epoch', 'val_bleu_text_epoch', 'val_wer_epoch', 'val_speech_nll_loss_epoch', 'val_speech_acc_epoch', 'val_asr_nll_loss_epoch', 'val_asr_acc_epoch', 'val_text_nll_loss_epoch', 'val_text_acc_epoch', 'val_mix_speech_nll_loss_epoch', 'val_mix_asr_nll_loss_epoch', 'val_mix_mlm_nll_loss_epoch', 'val_mix_speech_acc_epoch', 'val_mix_asr_acc_epoch', 'val_mix_mlm_acc_epoch', 'val_guide_loss_epoch', 'val_reg_loss_epoch']

# %%
train_acc = event_acc.Scalars('train_acc_speech_translate')

# %%
import numpy as np
import matplotlib.pyplot as plt

train_acc = event_acc.Scalars('train_acc_speech_translate')

steps = np.array([e.step for e in train_acc])
values = np.array([e.value for e in train_acc])

num_epochs = 10
total_steps = 3000
steps_per_epoch = total_steps // num_epochs  

start_step = steps[0] 

epoch_ids = ((steps - start_step) // steps_per_epoch).astype(int)

epoch_acc_dict = {}
for epoch in range(num_epochs):
    epoch_acc = values[epoch_ids == epoch]
    if len(epoch_acc) > 0:
        epoch_acc_dict[epoch + 1] = epoch_acc.mean()
    else:
        epoch_acc_dict[epoch + 1] = np.nan

epochs = np.arange(1, num_epochs + 1)
epoch_accs = np.array([epoch_acc_dict[e] for e in epochs])

# Plot
plt.figure(figsize=(8, 6))
plt.plot(epochs, epoch_accs, marker='o')
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("Train Accuracy (%)")
plt.title("Train Accuracy per Epoch")
plt.grid(True)
plt.show()

# %%
train_loss = event_acc.Scalars('train_nll_loss_speech_translate')

steps = np.array([e.step for e in train_loss])
values = np.array([e.value for e in train_loss])

num_epochs = 10
total_steps = 3000
steps_per_epoch = total_steps // num_epochs  

start_step = steps[0] 

epoch_ids = ((steps - start_step) // steps_per_epoch).astype(int)

epoch_acc_dict = {}
for epoch in range(num_epochs):
    epoch_acc = values[epoch_ids == epoch]
    if len(epoch_acc) > 0:
        epoch_acc_dict[epoch + 1] = epoch_acc.mean()
    else:
        epoch_acc_dict[epoch + 1] = np.nan

epochs = np.arange(1, num_epochs + 1)
epoch_accs = np.array([epoch_acc_dict[e] for e in epochs])

# Plot
plt.figure(figsize=(8, 6))
plt.plot(epochs, epoch_accs, marker='o')
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("Train Accuracy (%)")
plt.title("Train Accuracy per Epoch")
plt.grid(True)
plt.show()

# %%
val_acc = event_acc.Scalars('val_speech_acc_epoch')

steps = np.array([e.step for e in val_acc])
values = np.array([e.value for e in val_acc])

num_epochs = 10
total_steps = 3000
steps_per_epoch = total_steps // num_epochs  

start_step = steps[0] 

epoch_ids = ((steps - start_step) // steps_per_epoch).astype(int)

epoch_acc_dict = {}
for epoch in range(num_epochs):
    epoch_acc = values[epoch_ids == epoch]
    if len(epoch_acc) > 0:
        epoch_acc_dict[epoch + 1] = epoch_acc.mean()
    else:
        epoch_acc_dict[epoch + 1] = np.nan

epochs = np.arange(1, num_epochs + 1)
epoch_accs = np.array([epoch_acc_dict[e] for e in epochs])

# Plot
plt.figure(figsize=(8, 6))
plt.plot(epochs, epoch_accs, marker='o')
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("Train Accuracy (%)")
plt.title("Train Accuracy per Epoch")
plt.grid(True)
plt.show()

# %%
val_loss = event_acc.Scalars('val_speech_nll_loss_epoch')

steps = np.array([e.step for e in val_loss])
values = np.array([e.value for e in val_loss])

num_epochs = 10
total_steps = 3000
steps_per_epoch = total_steps // num_epochs  

start_step = steps[0] 

epoch_ids = ((steps - start_step) // steps_per_epoch).astype(int)

epoch_acc_dict = {}
for epoch in range(num_epochs):
    epoch_acc = values[epoch_ids == epoch]
    if len(epoch_acc) > 0:
        epoch_acc_dict[epoch + 1] = epoch_acc.mean()
    else:
        epoch_acc_dict[epoch + 1] = np.nan

epochs = np.arange(1, num_epochs + 1)
epoch_accs = np.array([epoch_acc_dict[e] for e in epochs])

# Plot
plt.figure(figsize=(8, 6))
plt.plot(epochs, epoch_accs, marker='o')
plt.xticks(epochs)
plt.xlabel("Epoch")
plt.ylabel("Train Accuracy (%)")
plt.title("Train Accuracy per Epoch")
plt.grid(True)
plt.show()

# %% [markdown]
# # test

# %%
test_events = [f for f in os.listdir(log_dir) if f.startswith('events.out')]
test_events = os.path.join(log_dir, sorted(test_events)[-1])

print(test_events)

test_events = EventAccumulator(event_path)
test_events.Reload()

print("Tất cả các scalar tag:")
print(test_events.Tags()['scalars'])
# Out:
# /kaggle/working/comsl_ja_cy_id/output/comsl_id2en/logs/ComST/default/events.out.tfevents.1748791931.9ffdbac2db6d.171.1
# Tất cả các scalar tag:
# ['lr-AdamW/pg1', 'lr-AdamW/pg2', 'train_acc_asr', 'train_nll_loss_asr', 'train_acc_text_translate', 'train_nll_loss_text_translate', 'train_acc_speech_translate', 'train_nll_loss_speech_translate', 'train_acc_mix_speech_translate', 'train_nll_loss_mix_speech_translate', 'train_acc_mix_asr', 'train_nll_loss_mix_asr', 'train_acc_mix_mlm', 'train_nll_loss_mix_mlm', 'train_guide_loss', 'train_reg_loss', 'epoch', 'val_bleu_spch_epoch', 'val_bleu_text_epoch', 'val_wer_epoch', 'val_speech_nll_loss_epoch', 'val_speech_acc_epoch', 'val_asr_nll_loss_epoch', 'val_asr_acc_epoch', 'val_text_nll_loss_epoch', 'val_text_acc_epoch', 'val_mix_speech_nll_loss_epoch', 'val_mix_asr_nll_loss_epoch', 'val_mix_mlm_nll_loss_epoch', 'val_mix_speech_acc_epoch', 'val_mix_asr_acc_epoch', 'val_mix_mlm_acc_epoch', 'val_guide_loss_epoch', 'val_reg_loss_epoch']
